# %% [markdown]
# # Simulazione testuale:
# *permette di scrivere studente a corsi*

# %% [markdown]
# Dati di esempio: *corsi disponibili* (id -> nome)

# %% [markdown]
# ### *Lista delle iscrizioni:*
# ##### Ogni elemento è un tupla <stromg>(id_Studente, id_Corso)</strong>
